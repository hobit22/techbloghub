# %% [markdown]
# # Multiple URL Content Extraction with WebBaseLoader
#
# 여러 기술 블로그 사이트들로부터 동시에 콘텐츠를 추출하고 분석하는 테스트

# %%
# 필요한 패키지 import
from langchain_community.document_loaders import WebBaseLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains.summarize import load_summarize_chain
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
import time
import os
from dotenv import load_dotenv

# Environment variables 로드
load_dotenv()

# OpenAI API 키 확인
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY가 .env 파일에 설정되지 않았습니다.")

print("✅ 모든 패키지 import 완료")
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ✅ 모든 패키지 import 완료

# %%
# 테스트할 기술 블로그 URL 목록
urls = [
    "http://thefarmersfront.github.io/blog/2025-delivery-jarvis-story/",  
    "https://medium.com/musinsa-tech/무진장을-맞아-후기-응답속도를-개선해보자-c92e0ae60f1e",
    "https://medium.com/daangn/ai-툴-개발은-처음이라-당근-비개발자-구성원들의-ai-도전기-fb62d2a6c2f3",
    "https://tech.socarcorp.kr/fe/2025/06/10/monorepo-ci-cd-pipeline.html",
    "https://d2.naver.com/news/6518915",
    "https://meetup.nhncloud.com/posts/394",
    "https://tech.kakao.com/posts/724",
    "https://techblog.lycorp.co.jp/ko/extracting-trending-keywords-from-openchat-messages",
    "https://developers.kakaomobility.com/docs/techblogs/address-structure-1/",
    "https://oliveyoung.tech/2025-09-08/gms-qa-strategy/",
    "https://toss.tech/article/tosspeople_hyunjung",
    "https://techblog.gccompany.co.kr/%EC%97%AC%EA%B8%B0%EC%96%B4%EB%95%8C-ci-cd-%EA%B0%9C%EC%84%A0%EA%B8%B0-part-5-slack%EC%9C%BC%EB%A1%9C-%EC%99%84%EC%84%B1%EB%90%98%EB%8A%94-%EB%B0%B0%ED%8F%AC-%EA%B0%80%EC%8B%9C%EC%84%B1-c38215b4ed61?source=rss----18356045d353---4",
    "https://techblog.woowahan.com/22767/",
]

print(f"📋 총 {len(urls)}개의 기술 블로그 URL 준비 완료")
print("\n🎯 테스트 대상 사이트들:")
for i, url in enumerate(urls, 1):
    print(f"   {i:2d}. {url}")
# Out:
# 📋 총 13개의 기술 블로그 URL 준비 완료
#
# 🎯 테스트 대상 사이트들:
#     1. http://thefarmersfront.github.io/blog/2025-delivery-jarvis-story/
#     2. https://medium.com/musinsa-tech/무진장을-맞아-후기-응답속도를-개선해보자-c92e0ae60f1e
#     3. https://medium.com/daangn/ai-툴-개발은-처음이라-당근-비개발자-구성원들의-ai-도전기-fb62d2a6c2f3
#     4. https://tech.socarcorp.kr/fe/2025/06/10/monorepo-ci-cd-pipeline.html
#     5. https://d2.naver.com/news/6518915
#     6. https://meetup.nhncloud.com/posts/394
#     7. https://tech.kakao.com/posts/724
#     8. https://techblog.lycorp.co.jp/ko/extracting-trending-keywords-from-openchat-messages
#     9. https://developers.kakaomobility.com/docs/techblogs/address-structure-1/
#    10. https://oliveyoung.tech/2025-09-08/gms-qa-strategy/
#    11. https://toss.tech/article/tosspeople_hyunjung
#    12. https://techblog.gccompany.co.kr/%EC%97%AC%EA%B8%B0%EC%96%B4%EB%95%8C-ci-cd-%EA%B0%9C%EC%84%A0%EA%B8%B0-part-5-slack%EC%9C%BC%EB%A1%9C-%EC%99%84%EC%84%B1%EB%90%98%EB%8A%94-%EB%B0%B0%ED%8F%AC-%EA%B0%80%EC%8B%9C%EC%84%B1-c38215b4ed61?source=rss----18356045d353---4
#    13. https://techblog.woowahan.com/22767/

# %%
# WebBaseLoader 설정 및 초기화
def setup_webbase_loader(urls_list, requests_per_second=2):
    """
    WebBaseLoader를 설정하고 초기화하는 함수
    """
    loader = WebBaseLoader(urls_list)
    
    # 요청 설정 - test0925.py 참고
    loader.requests_kwargs = {
        'verify': False,  # SSL 검증 비활성화
        'timeout': 30,    # 타임아웃 설정
    }
    
    # 동시 요청 속도 제어
    loader.requests_per_second = requests_per_second
    
    return loader

# 텍스트 분할기 설정 - test0925.py 참고
text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=3000,     # 쪼개는 글자수
    chunk_overlap=300,   # 오버랩 글자수
    length_function=len,
    is_separator_regex=False,
)

print("✅ WebBaseLoader 및 텍스트 분할기 설정 완료")
# Out:
# ✅ WebBaseLoader 및 텍스트 분할기 설정 완료

# %%
# 방법 1: 모든 URL을 한 번에 처리하기
print("🚀 방법 1: 모든 URL을 한 번에 처리하기")
print("-" * 60)

start_time = time.time()

try:
    # 모든 URL을 한 번에 로드
    loader = setup_webbase_loader(urls, requests_per_second=3)
    docs = loader.load_and_split(text_splitter)
    
    end_time = time.time()
    processing_time = end_time - start_time
    
    print(f"✅ 성공: {len(docs)}개 청크 추출 완료")
    print(f"⏱️  처리 시간: {processing_time:.2f}초")
    print(f"📊 평균 처리 시간: {processing_time/len(urls):.2f}초/URL")
    
except Exception as e:
    print(f"❌ 오류 발생: {e}")
    docs = []
# Out:
# 🚀 방법 1: 모든 URL을 한 번에 처리하기
# ------------------------------------------------------------
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'helloworld.kurly.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tech.socarcorp.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'd2.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'meetup.nhncloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tech.kakao.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.lycorp.co.jp'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'developers.kakaomobility.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oliveyoung.tech'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'toss.tech'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.gccompany.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.gccompany.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.woowahan.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Created a chunk of size 6177, which is longer than the specified 3000
# Created a chunk of size 5483, which is longer than the specified 3000
# Created a chunk of size 4151, which is longer than the specified 3000
# Created a chunk of size 3724, which is longer than the specified 3000
# Created a chunk of size 9321, which is longer than the specified 3000
# ✅ 성공: 28개 청크 추출 완료
# ⏱️  처리 시간: 9.51초
# 📊 평균 처리 시간: 0.73초/URL

# %%
# 방법 2: 개별 URL 처리하기 (실패 시 대안)
print("\n🔄 방법 2: 개별 URL 처리하기")
print("-" * 60)

individual_docs = []
successful_urls = []
failed_urls = []

start_time = time.time()

for i, url in enumerate(urls, 1):
    try:
        print(f"📥 {i:2d}/{len(urls)} 처리 중: {url}")
        
        # 개별 URL 로더 생성
        single_loader = setup_webbase_loader([url], requests_per_second=1)
        single_docs = single_loader.load_and_split(text_splitter)
        
        individual_docs.extend(single_docs)
        successful_urls.append(url)
        
        print(f"   ✅ 성공: {len(single_docs)}개 청크 추출")
        
    except Exception as e:
        failed_urls.append(url)
        print(f"   ❌ 실패: {str(e)[:100]}...")
    
    # 과도한 요청 방지를 위한 딜레이
    time.sleep(1)

end_time = time.time()
processing_time = end_time - start_time

print(f"\n📊 개별 처리 결과:")
print(f"   ✅ 성공: {len(successful_urls)}개 URL")
print(f"   ❌ 실패: {len(failed_urls)}개 URL")
print(f"   📄 총 청크: {len(individual_docs)}개")
print(f"   ⏱️  총 처리 시간: {processing_time:.2f}초")
# Out:
# 🔄 방법 2: 개별 URL 처리하기
# ------------------------------------------------------------
# 📥  1/13 처리 중: http://thefarmersfront.github.io/blog/2025-delivery-jarvis-story/
#    ✅ 성공: 2개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'helloworld.kurly.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥  2/13 처리 중: https://medium.com/musinsa-tech/무진장을-맞아-후기-응답속도를-개선해보자-c92e0ae60f1e
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Created a chunk of size 6177, which is longer than the specified 3000
#    ✅ 성공: 1개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Created a chunk of size 5483, which is longer than the specified 3000
# 📥  3/13 처리 중: https://medium.com/daangn/ai-툴-개발은-처음이라-당근-비개발자-구성원들의-ai-도전기-fb62d2a6c2f3
#    ✅ 성공: 1개 청크 추출
# 📥  4/13 처리 중: https://tech.socarcorp.kr/fe/2025/06/10/monorepo-ci-cd-pipeline.html
#    ✅ 성공: 2개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tech.socarcorp.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥  5/13 처리 중: https://d2.naver.com/news/6518915
#    ✅ 성공: 1개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'd2.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥  6/13 처리 중: https://meetup.nhncloud.com/posts/394
#    ✅ 성공: 1개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'meetup.nhncloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥  7/13 처리 중: https://tech.kakao.com/posts/724
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tech.kakao.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    ✅ 성공: 1개 청크 추출
# 📥  8/13 처리 중: https://techblog.lycorp.co.jp/ko/extracting-trending-keywords-from-openchat-messages
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.lycorp.co.jp'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Created a chunk of size 4151, which is longer than the specified 3000
# Created a chunk of size 3724, which is longer than the specified 3000
#    ✅ 성공: 5개 청크 추출
# 📥  9/13 처리 중: https://developers.kakaomobility.com/docs/techblogs/address-structure-1/
#    ✅ 성공: 2개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'developers.kakaomobility.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥 10/13 처리 중: https://oliveyoung.tech/2025-09-08/gms-qa-strategy/
#    ✅ 성공: 4개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oliveyoung.tech'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥 11/13 처리 중: https://toss.tech/article/tosspeople_hyunjung
#    ✅ 성공: 1개 청크 추출
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'toss.tech'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 📥 12/13 처리 중: https://techblog.gccompany.co.kr/%EC%97%AC%EA%B8%B0%EC%96%B4%EB%95%8C-ci-cd-%EA%B0%9C%EC%84%A0%EA%B8%B0-part-5-slack%EC%9C%BC%EB%A1%9C-%EC%99%84%EC%84%B1%EB%90%98%EB%8A%94-%EB%B0%B0%ED%8F%AC-%EA%B0%80%EC%8B%9C%EC%84%B1-c38215b4ed61?source=rss----18356045d353---4
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.gccompany.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'medium.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.gccompany.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Created a chunk of size 9321, which is longer than the specified 3000
#    ✅ 성공: 1개 청크 추출
# 📥 13/13 처리 중: https://techblog.woowahan.com/22767/
# /Users/apple/IdeaProjects/techbloghub/python/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'techblog.woowahan.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    ✅ 성공: 6개 청크 추출
#
# 📊 개별 처리 결과:
#    ✅ 성공: 13개 URL
#    ❌ 실패: 0개 URL
#    📄 총 청크: 28개
#    ⏱️  총 처리 시간: 19.12초

# %%
# 성공한 결과 분석
final_docs = docs if docs else individual_docs

if final_docs:
    print("\n📈 콘텐츠 추출 결과 분석")
    print("=" * 80)
    
    # 사이트별 통계
    site_stats = {}
    for doc in final_docs:
        source = doc.metadata.get('source', 'Unknown')
        if source not in site_stats:
            site_stats[source] = {
                'chunks': 0,
                'total_length': 0,
                'title': doc.metadata.get('title', '제목 없음')[:50]
            }
        site_stats[source]['chunks'] += 1
        site_stats[source]['total_length'] += len(doc.page_content)
    
    for i, (url, stats) in enumerate(site_stats.items(), 1):
        print(f"\n🌐 사이트 {i}: {url}")
        print(f"   📝 제목: {stats['title']}")
        print(f"   📊 청크 수: {stats['chunks']}개")
        print(f"   📏 총 길이: {stats['total_length']:,}자")
        print(f"   📄 평균 청크 크기: {stats['total_length']//stats['chunks']:,}자")
        
        # 첫 번째 청크의 미리보기
        first_chunk = next((doc for doc in final_docs if doc.metadata.get('source') == url), None)
        if first_chunk:
            preview = first_chunk.page_content[:200].replace('\n', ' ').strip()
            print(f"   👀 미리보기: {preview}...")
        
        print("-" * 60)
else:
    print("\n❌ 추출된 콘텐츠가 없습니다.")
# Out:
# 📈 콘텐츠 추출 결과 분석
# ================================================================================
#
# 🌐 사이트 1: http://thefarmersfront.github.io/blog/2025-delivery-jarvis-story/
#    📝 제목: 우리 팀에도 Jarvis 가 생겼다 – 생성형 AI 로 만든 에러 분석가 이야기 - 컬리
#    📊 청크 수: 2개
#    📏 총 길이: 5,581자
#    📄 평균 청크 크기: 2,790자
#    👀 미리보기: 우리 팀에도 Jarvis 가 생겼다 – 생성형 AI 로 만든 에러 분석가 이야기 - 컬리 기술 블로그   Kurly Tech Blog  우리 팀에도 Jarvis 가 생겼다 – 생성형 AI 로 만든 에러 분석가 이야기  팀 내에서 생성형 AI 를 활용한 사례를 공유합니다.  김성준 게시 날짜: 2025.07.01.  왜 에러 로그는 항상 늦게 처리되는가? 에...
# ------------------------------------------------------------
#
# 🌐 사이트 2: https://medium.com/musinsa-tech/무진장을-맞아-후기-응답속도를-개선해보자-c92e0ae60f1e
#    📝 제목: 무진장을 맞아, 후기 응답속도를 개선해보자. 안녕하세요. 무신사 구매개발실 회원개발팀에서
#    📊 청크 수: 1개
#    📏 총 길이: 6,177자
#    📄 평균 청크 크기: 6,177자
#    👀 미리보기: 무진장을 맞아, 후기 응답속도를 개선해보자. 안녕하세요. 무신사 구매개발실 회원개발팀에서 백엔드 엔지니어로 일하고… | by Soyoun Kim | MUSINSA tech | MediumSitemapOpen in appSign upSign inMedium LogoWriteSign upSign inMUSINSA tech·팀 무신사의 테크 이야기를 공유합니다....
# ------------------------------------------------------------
#
# 🌐 사이트 3: https://medium.com/daangn/ai-툴-개발은-처음이라-당근-비개발자-구성원들의-ai-도전기-fb62d2a6c2f3
#    📝 제목: AI 툴 개발은 처음이라, 당근 비개발자 구성원들의 AI 도전기 — 당근 AI Show &
#    📊 청크 수: 1개
#    📏 총 길이: 5,483자
#    📄 평균 청크 크기: 5,483자
#    👀 미리보기: AI 툴 개발은 처음이라, 당근 비개발자 구성원들의 AI 도전기 — 당근 AI Show & Tell #1 | by 당근 | 당근 테크 블로그 | MediumSitemapOpen in appSign upSign inMedium LogoWriteSign upSign in당근 테크 블로그·당근은 동네 이웃 간의 연결을 도와 따뜻하고 활발한 교류가 있는 지역 사회...
# ------------------------------------------------------------
#
# 🌐 사이트 4: https://tech.socarcorp.kr/fe/2025/06/10/monorepo-ci-cd-pipeline.html
#    📝 제목:
#     FE Core팀의 CI 속도전: 캐시 전략을 활용한 병렬 빌드 - SOCAR Te
#    📊 청크 수: 2개
#    📏 총 길이: 4,634자
#    📄 평균 청크 크기: 2,317자
#    👀 미리보기: FE Core팀의 CI 속도전: 캐시 전략을 활용한 병렬 빌드 - SOCAR Tech Blog          SOCAR Tech Blog        Menu          🏠 Home   ✏️ Posts   📔 Categories   🏷 Tags   ✍🏻 Authors   FE Core팀의 CI 속도전: 캐시 전략을 활용한 병렬 빌드 Monorepo...
# ------------------------------------------------------------
#
# 🌐 사이트 5: https://d2.naver.com/news/6518915
#    📝 제목: NAVER D2
#    📊 청크 수: 1개
#    📏 총 길이: 163자
#    📄 평균 청크 크기: 163자
#    👀 미리보기: NAVER D2  naver D2  메뉴  Hello world D2 News About D2  검색   검색  NAVER Developers DEVIEW OpenSource D2 STARTUP FACTORY   Copyright © NAVER Corp. All Rights Reserved....
# ------------------------------------------------------------
#
# 🌐 사이트 6: https://meetup.nhncloud.com/posts/394
#    📝 제목: 모바일 앱 난독화(Mobile App Obfuscation)란? : NHN Cloud Me
#    📊 청크 수: 1개
#    📏 총 길이: 462자
#    📄 평균 청크 크기: 462자
#    👀 미리보기: 모바일 앱 난독화(Mobile App Obfuscation)란? : NHN Cloud Meetup  본문으로 바로가기  NHN Cloud NHN Cloud Meetup!  검색  검색 영역  검색어 입력  텍스트 지우기 검색  등록일 {{post.regDt}} 조회수 {{post.viewCount}}  첨부파일  {{attachment.fileName}}...
# ------------------------------------------------------------
#
# 🌐 사이트 7: https://tech.kakao.com/posts/724
#    📝 제목: Kanana 언어모델에 추론 기능 붙여보기 (feat. Kanana-1.5) - tech.
#    📊 청크 수: 1개
#    📏 총 길이: 813자
#    📄 평균 청크 크기: 813자
#    👀 미리보기: Kanana 언어모델에 추론 기능 붙여보기 (feat. Kanana-1.5) - tech.kakao.com  이 페이지를 실행하려면 자바스크립트를 사용해야 합니다.  본문 바로가기메뉴 바로가기검색하기메뉴 열기테크 카카오 메뉴BlogEventsCareersKakao Developers새창열림 Search 검색하기Kanana 언어모델에 추론 기능 붙여보기 (f...
# ------------------------------------------------------------
#
# 🌐 사이트 8: https://techblog.lycorp.co.jp/ko/extracting-trending-keywords-from-openchat-messages
#    📝 제목: 오픈챗 메시지들로부터 트렌딩 키워드 추출하기
#    📊 청크 수: 5개
#    📏 총 길이: 13,876자
#    📄 평균 청크 크기: 2,775자
#    👀 미리보기: 오픈챗 메시지들로부터 트렌딩 키워드 추출하기Skip to main contentSkip to footerOpen MenuCorporate InformationNewsServiceTechnologyPrivacy & SecurityInvestor RelationsSustainabilityCareers한국어English한국어SearchLY Corporation...
# ------------------------------------------------------------
#
# 🌐 사이트 9: https://developers.kakaomobility.com/docs/techblogs/address-structure-1/
#    📝 제목: 주소 데이터 활용을 위한 우리나라 행정구역 이해하기 | 카카오모빌리티 디벨로퍼스 | 카카오
#    📊 청크 수: 2개
#    📏 총 길이: 4,369자
#    📄 평균 청크 크기: 2,184자
#    👀 미리보기: 주소 데이터 활용을 위한 우리나라 행정구역 이해하기 | 카카오모빌리티 디벨로퍼스 | 카카오모빌리티 디벨로퍼스...
# ------------------------------------------------------------
#
# 🌐 사이트 10: https://oliveyoung.tech/2025-09-08/gms-qa-strategy/
#    📝 제목: 빅뱅 배포, QA는 어떻게 살아 남았나: GMS 프로젝트 테스트 전략 백서 | 올리브영 테
#    📊 청크 수: 4개
#    📏 총 길이: 9,535자
#    📄 평균 청크 크기: 2,383자
#    👀 미리보기: 빅뱅 배포, QA는 어떻게 살아 남았나: GMS 프로젝트 테스트 전략 백서 | 올리브영 테크블로그올리브영 테크블로그채용정보회사정보Tech빅뱅 배포, QA는 어떻게 살아 남았나: GMS 프로젝트 테스트 전략 백서물류 시스템 구축 성공의 열쇠: 설계부터 E2E 테스트, 실시간 품질 모니터링까지2025.09.08 올리브영에서 SCM 도메인 QA 엔지니어 겸민입니...
# ------------------------------------------------------------
#
# 🌐 사이트 11: https://toss.tech/article/tosspeople_hyunjung
#    📝 제목: 토스 피플 : 새로운 길을 만들 땐 내 선택을 믿는다
#    📊 청크 수: 1개
#    📏 총 길이: 3,913자
#    📄 평균 청크 크기: 3,913자
#    👀 미리보기: 토스 피플 : 새로운 길을 만들 땐 내 선택을 믿는다SLASHSLASHSLASH 24SLASH 23SLASH 22SLASH 21SIMPLICITY구독하기채용 바로가기토스 피플 : 새로운 길을 만들 땐 내 선택을 믿는다이현정2025년 8월 28일Product Designer 현정 님은 토스에서 계속 새로운 임팩트를 만들어가고 있어요. B2B부터 광고, 이제는...
# ------------------------------------------------------------
#
# 🌐 사이트 12: https://techblog.gccompany.co.kr/%EC%97%AC%EA%B8%B0%EC%96%B4%EB%95%8C-ci-cd-%EA%B0%9C%EC%84%A0%EA%B8%B0-part-5-slack%EC%9C%BC%EB%A1%9C-%EC%99%84%EC%84%B1%EB%90%98%EB%8A%94-%EB%B0%B0%ED%8F%AC-%EA%B0%80%EC%8B%9C%EC%84%B1-c38215b4ed61?source=rss----18356045d353---4
#    📝 제목: 여기어때 CI/CD 개선기 Part 5: Slack으로 완성되는 배포 가시성 | by Ch
#    📊 청크 수: 1개
#    📏 총 길이: 9,321자
#    📄 평균 청크 크기: 9,321자
#    👀 미리보기: 여기어때 CI/CD 개선기 Part 5: Slack으로 완성되는 배포 가시성 | by Chloe 클로이 허윤지 / DevOps팀 | Sep, 2025 | 여기어때 기술블로그SitemapOpen in appSign upSign inMedium LogoWriteSign upSign in여기어때 기술블로그·Follow publicationGC Company Te...
# ------------------------------------------------------------
#
# 🌐 사이트 13: https://techblog.woowahan.com/22767/
#    📝 제목: Spring Cache(@Cacheable) + Spring Data Redis 사용 시
#    📊 청크 수: 6개
#    📏 총 길이: 15,685자
#    📄 평균 청크 크기: 2,614자
#    👀 미리보기: Spring Cache(@Cacheable) + Spring Data Redis 사용 시 record 직렬화 오류 원인과 해결 | 우아한형제들 기술블로그     AIAPPAWSBackendCultureDataDeep LearningDesignEducationGenAIInfraMachine LearningMLOpsNLPPMProgramming GeneralQ...
# ------------------------------------------------------------

# %%
# 실패한 URL들 상세 분석
if failed_urls:
    print("\n⚠️  실패한 URL 분석")
    print("=" * 50)
    
    for i, url in enumerate(failed_urls, 1):
        print(f"{i}. {url}")
        
        # 간단한 재시도
        try:
            retry_loader = WebBaseLoader([url])
            retry_loader.requests_kwargs = {'verify': False, 'timeout': 10}
            retry_docs = retry_loader.load()
            if retry_docs:
                print(f"   ✅ 재시도 성공: {len(retry_docs[0].page_content)} 문자")
            else:
                print(f"   ❌ 재시도 실패: 빈 콘텐츠")
        except Exception as retry_error:
            print(f"   ❌ 재시도 실패: {str(retry_error)[:50]}...")

# %%
# 각 URL별로 개별 요약 생성
if final_docs:
    print("\\n🤖 URL별 개별 AI 요약 생성")
    print("=" * 80)
    
    # 템플릿 설정 - test0925.py 참고
    template = '''다음의 내용을 한글로 요약해줘:\\n\\n{text}'''
    
    combine_template = '''{text}\\n\\n요약의 결과는 다음의 형식으로 작성해줘:
제목: 글의 제목
주요내용: 한 줄로 요약된 내용
작성자: 추정된 작성자 또는 블로그명
내용: 주요내용을 불렛포인트 형식으로 작성
'''
    
    # 템플릿 생성
    prompt = PromptTemplate(template=template, input_variables=['text'])
    combine_prompt = PromptTemplate(template=combine_template, input_variables=['text'])
    
    # LLM 객체 생성
    llm = ChatOpenAI(temperature=0, model_name='gpt-4o-mini')
    
    # 요약 체인 생성
    chain = load_summarize_chain(
        llm,
        map_prompt=prompt,
        combine_prompt=combine_prompt,
        chain_type="map_reduce",
        verbose=False
    )
    
    # 각 URL별로 문서들을 그룹화하고 개별 요약 생성
    url_groups = {}
    for doc in final_docs:
        source = doc.metadata.get('source', 'Unknown')
        if source not in url_groups:
            url_groups[source] = []
        url_groups[source].append(doc)
    
    print(f"📊 총 {len(url_groups)}개 사이트의 콘텐츠를 개별 요약합니다...")
    
    summaries = {}
    
    for i, (url, docs_for_url) in enumerate(url_groups.items(), 1):
        try:
            print(f"🔄 {i}/{len(url_groups)} 요약 생성 중...")
            print(f"📍 URL: {url}")
            print(f"📄 청크 수: {len(docs_for_url)}개")
            
            # 요약 실행
            summary = chain.invoke({'input_documents': docs_for_url})
            summaries[url] = summary['output_text']
            
            print(f"✅ 요약 완료")
            print("📋 요약 결과:")
            print("-" * 60)
            print(summary['output_text'])
            print("=" * 80)
            print()
            
        except Exception as e:
            print(f"❌ 요약 생성 실패: {e}")
            print("-" * 60)
            summaries[url] = f"요약 생성 실패: {e}"
            
        # API 호출 간격 조절
        time.sleep(2)
    
    print(f"🎯 전체 요약 완료: {len(summaries)}개 사이트")
    
else:
    print("❌ 요약할 문서가 없습니다.")
# Out:
# \n🤖 URL별 개별 AI 요약 생성
# ================================================================================
# 📊 총 13개 사이트의 콘텐츠를 개별 요약합니다...
# 🔄 1/13 요약 생성 중...
# 📍 URL: http://thefarmersfront.github.io/blog/2025-delivery-jarvis-story/
# 📄 청크 수: 2개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 생성형 AI를 활용한 에러 분석가 'Jarvis'의 도입과 발전 과정
# 주요내용: Jarvis는 에러 로그 분석을 자동화하여 개발자들이 신속하게 문제를 해결할 수 있도록 돕는 AI 시스템이다.
# 작성자: 김성준 (컬리 기술 블로그)
# 내용:
# - 에러 로그는 개발자들에게 복잡하고 시간이 많이 소요되는 문제로, Jarvis를 통해 해결하고자 함.
# - 초기 AI 응답 품질이 낮았으나, 프롬프트 재구성을 통해 개선됨.
# - 팀원들이 Jarvis의 제안을 잘 참고하지 않는 문제를 발견하고, 정보 부족이 원인임을 인식.
# - MCP(Model Context Protocol)를 도입하여 Jarvis가 더 풍부한 맥락을 이해하도록 개선.
# - Jarvis는 실제 운영 환경에서 빠르게 문제를 분석하고 해결 방안을 제시함.
# - 향후 팀원들의 Slack 대화 내용을 학습하여 더욱 깊이 있는 해결책을 제시할 계획.
# - 개발 과정에서의 문제 해결 경험과 팀원들의 협력이 중요하다는 점 강조.
# ================================================================================
#
# 🔄 2/13 요약 생성 중...
# 📍 URL: https://medium.com/musinsa-tech/무진장을-맞아-후기-응답속도를-개선해보자-c92e0ae60f1e
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 무신사 후기 서비스 성능 개선 사례
# 주요내용: 무신사 후기 서비스의 응답 속도를 개선하여 이벤트 대비 안정성을 확보했다.
# 작성자: 김소연
# 내용:
# - '무진장 여름 블랙프라이데이' 이벤트 대비 후기 서비스의 응답 속도 개선
# - 예상 트래픽 3배 증가에 따른 사전 안정성 검토 실시
# - 전체 후기 목록 페이지 평균 응답 지연 시간 250ms에서 개선 필요
# - 상품 단위 캐싱 전략 도입으로 평균 응답 속도 300ms에서 100ms로 감소
# - 요청량 증가에 따른 성능 향상 구조로 변경
# - 개선된 시스템으로 안정적인 운영 및 비용 절감 효과 달성
# - 지속적인 서비스 개선의 필요성 강조
# ================================================================================
#
# 🔄 3/13 요약 생성 중...
# 📍 URL: https://medium.com/daangn/ai-툴-개발은-처음이라-당근-비개발자-구성원들의-ai-도전기-fb62d2a6c2f3
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 당근의 AI Show & Tell: 비개발자의 AI 프로젝트 경험 공유
# 주요내용: 비개발자들이 AI를 활용한 다양한 프로젝트 경험을 공유하며 실험 문화를 확산하고 있다.
# 작성자: 당근
#
# 내용:
# - 매주 'AI Show & Tell'을 통해 비개발자 구성원들의 AI 프로젝트 경험 공유
# - 디자이너 Hazel: 피그마 플러그인 'Ratiosnap' 개발로 디자인 효율성 향상
# - CEO Staff Kyle: 'AI 프로젝트 캐처'로 전사 AI 프로젝트 정보 통합 및 협업 촉진
# - 운영 매니저 Sang: AI를 활용한 정규표현식 생성기 및 정책 점검 도구 개발로 운영 효율성 개선
# - 비개발자도 AI를 활용해 문제를 해결할 수 있는 가능성 제시
# - 당근 내 AI 실험 문화의 확산과 새로운 가능성 발견을 위한 지속적인 노력
# ================================================================================
#
# 🔄 4/13 요약 생성 중...
# 📍 URL: https://tech.socarcorp.kr/fe/2025/06/10/monorepo-ci-cd-pipeline.html
# 📄 청크 수: 2개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: CI 파이프라인 개선을 통한 빌드 시간 단축 및 안정성 향상
# 주요내용: FE Core팀은 CI 파이프라인의 효율성을 높이기 위해 다양한 전략을 도입하여 빌드 시간을 최대 84% 단축하고 안정성을 강화했다.
# 작성자: 아놀드, FE CORE 팀 프론트엔드 개발자
#
# 내용:
# - 기존 CI 파이프라인은 30개 이상의 프로젝트로 인해 평균 20분 이상의 빌드 시간이 소요됨.
# - Runner 사양 개선으로 빌드 시간을 약 10분대로 단축.
# - GitHub Workflow의 Matrix 전략을 도입하여 병렬 빌드 수행.
# - turborepo의 dry-run 기능을 활용하여 캐시 상태를 점검하고 오버헤드 최소화.
# - 빌드 검증 단계를 추가하여 개별 빌드 결과를 status check로 기록.
# - 전체 CI 파이프라인 빌드 시간을 최대 84% 단축, 캐시 적중 시 오버헤드 최소화.
# - 향후 지속적인 자동화와 최적화 방안을 탐구할 계획.
# ================================================================================
#
# 🔄 5/13 요약 생성 중...
# 📍 URL: https://d2.naver.com/news/6518915
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: NAVER D2 플랫폼 소개
# 주요내용: NAVER D2는 개발자 관련 다양한 서비스를 제공하는 플랫폼이다.
# 작성자: NAVER Corp.
# 내용:
# - NAVER D2는 개발자 관련 플랫폼으로 다양한 메뉴 제공
# - D2 뉴스: 최신 개발 관련 뉴스 및 정보 제공
# - D2 스타트업 팩토리: 스타트업 지원 및 육성 프로그램 운영
# - 저작권은 NAVER Corp.에 소속됨
# ================================================================================
#
# 🔄 6/13 요약 생성 중...
# 📍 URL: https://meetup.nhncloud.com/posts/394
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 모바일 앱 난독화(Mobile App Obfuscation)
# 주요내용: 앱의 소스 코드를 이해하기 어렵게 만들어 보안성을 높이는 기술
# 작성자: NHN Cloud Meetup
#
# 내용:
# - 모바일 앱 난독화는 소스 코드를 복잡하게 만들어 해킹 및 역공학을 방지하는 기술
# - NHN Cloud Meetup에서 이 주제를 다루고 있음
# - 관련 정보는 NHN Cloud의 공식 웹사이트에서 확인 가능
# ================================================================================
#
# 🔄 7/13 요약 생성 중...
# 📍 URL: https://tech.kakao.com/posts/724
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: Kanana 언어모델에 추론 기능 추가하기
# 주요내용: Kanana-1.5 버전을 활용하여 언어모델의 성능을 향상시키는 방법을 설명.
# 작성자: 추정된 작성자 또는 블로그명
# 내용:
# - Kanana-1.5 버전의 특징 및 장점 소개
# - 언어모델에 추론 기능을 추가하는 기술적 세부사항 설명
# - 구현 과정 및 코드 예시 제공
# - 성능 향상 결과 및 평가 방법 논의
# ================================================================================
#
# 🔄 8/13 요약 생성 중...
# 📍 URL: https://techblog.lycorp.co.jp/ko/extracting-trending-keywords-from-openchat-messages
# 📄 청크 수: 5개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: LINE 오픈챗에서 트렌딩 키워드 추출 방법
#
# 주요내용: LINE 오픈챗 메시지 콘텐츠에서 트렌딩 키워드를 효과적으로 추출하고 중복 메시지를 제거하는 방법을 설명.
#
# 작성자: 추정된 작성자 또는 블로그명
#
# 내용:
# - 오픈챗 메인 화면에 메시지 콘텐츠 노출 방안 구상.
# - 메시지 텍스트의 등장 빈도를 분석하여 급증한 단어를 트렌딩 키워드로 정의.
# - Z-테스트 통계량을 사용하여 단어의 빈도 차이를 계량화하고, 최소 30% 이상 증가한 단어 선정.
# - MinHash 기법을 활용하여 중복 메시지 제거 및 클러스터링 수행.
# - k값 조정에 따른 클러스터링 결과 변화 및 SetDiv 지표를 통한 중첩도 측정.
# - 동시 발생 빈도를 활용하여 트렌딩 키워드 품질 향상, NPMI 기반의 통계적 기법 도입.
# - MMR 기법을 통해 키워드 간 유사도를 고려하여 다양성 확보.
# - 향후 LLM을 활용한 트렌딩 리포트 생성 등 다양한 활용 방안 기대.
# ================================================================================
#
# 🔄 9/13 요약 생성 중...
# 📍 URL: https://developers.kakaomobility.com/docs/techblogs/address-structure-1/
# 📄 청크 수: 2개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 주소 데이터 활용을 위한 우리나라 행정구역 이해하기
# 주요내용: 한국의 행정구역 체계와 주소 데이터 활용 방법에 대한 설명
# 작성자: 카카오모빌리티 디벨로퍼스
# 내용:
# - 한국의 행정구역은 광역자치단체, 기초자치단체, 읍·면·동, 리로 나뉜다.
# - 법정동은 법적으로 인정된 단위로 변경이 적고, 행정동은 주민센터 운영을 위해 현실적인 생활 단위를 기준으로 설정된다.
# - 주소 데이터는 서비스 목적에 따라 행정동 또는 법정동을 선택해 사용한다.
# - 각 행정구역에는 고유 코드가 있어 데이터 연동과 지역 분석에 유용하다.
# - 법정동과 행정동의 코드 체계는 10자리 숫자로 구성되어 있으며, 각 자리마다 특정한 의미가 있다.
# - 주소 데이터의 구조와 활용을 이해하는 것이 중요하며, 다음 편에서는 주소 정보의 구조와 코드 체계에 대해 다룰 예정이다.
# ================================================================================
#
# 🔄 10/13 요약 생성 중...
# 📍 URL: https://oliveyoung.tech/2025-09-08/gms-qa-strategy/
# 📄 청크 수: 4개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: GMS 프로젝트의 QA 과정과 중요성
#
# 주요내용: GMS 프로젝트의 QA 과정에서 시스템 안정성과 데이터 정합성을 확보하기 위한 다양한 테스트 전략이 필요했다.
#
# 작성자: 민 (올리브영 SCM 도메인 QA 엔지니어)
#
# 내용:
# - GMS 프로젝트는 '빅뱅 배포' 방식을 채택하여 기존 시스템을 한 번에 전환하는 복잡한 도전.
# - QA 팀은 시스템 안정성에 영향을 줄 수 있는 다양한 리스크를 식별하고 테스트 전략을 수립.
# - 상품, 입고, 출고, 배송의 주요 카테고리를 기준으로 전체 워크플로우 설계 및 E2E 통합 테스트 필요성 확인.
# - 다양한 외부 시스템과의 연계 및 데이터 인터페이스 방식에 따라 체계적인 테스트 케이스 설계.
# - 기능 단위 테스트에서 결함 발견율에 집중하여 취약점 사전 식별.
# - Negative Test를 통해 오류 처리 및 필수 파라미터 누락 검증.
# - 동시성 테스트로 복잡한 운영 환경에서의 충돌 예방.
# - 통합 테스트 단계에서 E2E 시나리오 기반으로 기능 검증 및 메시지 흐름과 데이터 일관성 검증.
# - Interface Contract Test로 스키마 불일치 문제 사전 차단.
# - UAT를 통해 실제 센터 환경에서의 리스크 파악 및 예상치 못한 이슈 사전 탐지.
# - 오픈 이후 QA의 역할 지속, Datadog 기반의 커스텀 모니터링 룰 구축으로 조용한 실패 실시간 탐지.
# - QA 접근 방식은 매번 새로운 고민과 선택이 필요하며, 최적의 테스트 전략 설계의 중요성 강조.
# - 올리브영 QA팀의 채용 공고 및 새로운 품질 경험을 함께 만들어 갈 인재 모집.
# ================================================================================
#
# 🔄 11/13 요약 생성 중...
# 📍 URL: https://toss.tech/article/tosspeople_hyunjung
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 이현정, 토스에서의 Product Designer 여정
# 주요내용: 이현정은 UX/UI 분야로 전향하여 토스에서 사용자 경험 개선에 기여하고 있다.
# 작성자: 추정된 작성자 또는 블로그명
#
# 내용:
# - 이현정은 패션 업계에서 시작한 커리어를 UX/UI 분야로 전환.
# - 더 논리적이고 합리적인 의사결정 구조를 원함.
# - 토스 입사 초기에는 기대에 미치지 못했으나, 애즈 플랫폼에서 성과를 올림.
# - '혜택 탭'을 맡아 사용자 경험을 해치지 않으면서 광고 도입을 고민.
# - 현재 그로스팀에서 사용자 유입과 유지 전략을 개발 중.
# - 과거의 빠른 판단과 실행이 현재 성과에 기여했다고 강조.
# - 앞으로도 새로운 길을 개척하고 싶다는 포부를 밝힘.
# ================================================================================
#
# 🔄 12/13 요약 생성 중...
# 📍 URL: https://techblog.gccompany.co.kr/%EC%97%AC%EA%B8%B0%EC%96%B4%EB%95%8C-ci-cd-%EA%B0%9C%EC%84%A0%EA%B8%B0-part-5-slack%EC%9C%BC%EB%A1%9C-%EC%99%84%EC%84%B1%EB%90%98%EB%8A%94-%EB%B0%B0%ED%8F%AC-%EA%B0%80%EC%8B%9C%EC%84%B1-c38215b4ed61?source=rss----18356045d353---4
# 📄 청크 수: 1개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: 여기어때의 CI/CD 개선기 시리즈 5편 - GitLab CI와 ArgoCD를 활용한 배포 알림 시스템 개선
#
# 주요내용: GitLab CI와 ArgoCD를 통해 배포 알림 시스템을 통합하고 개선하여 DevOps팀의 효율성을 높임.
#
# 작성자: 여기어때 블로그
#
# 내용:
# - CI 알림 개선: Slack으로의 알림을 환경별 및 이벤트별로 세분화하여 일관된 알림 체계 구축.
# - Golang으로 개발한 pipeline-agent 도입: 스크립트 복잡성 감소, 다중 채널 전송 및 메시지 커스터마이징 용이.
# - CD 알림 개선: ArgoCD Notifications를 통해 EKS 배포 알림 통합, 팀별 알림 분리 및 노이즈 알림 제거.
# - Health/Sync 상태 모니터링: 세밀한 트리거와 템플릿 정의로 중요한 배포 이벤트 가시성 향상.
# - 결과: DevOps팀의 모니터링 및 대응 능력 향상, CI/CD 프로세스의 일관성 증대 및 배포 문화 발전.
# ================================================================================
#
# 🔄 13/13 요약 생성 중...
# 📍 URL: https://techblog.woowahan.com/22767/
# 📄 청크 수: 6개
# ✅ 요약 완료
# 📋 요약 결과:
# ------------------------------------------------------------
# 제목: Spring Data Redis에서 GenericJackson2JsonRedisSerializer의 직렬화 문제와 해결책
#
# 주요내용: Spring Data Redis에서 record와 @Cacheable을 사용할 때 발생하는 직렬화 문제와 그 해결 방법을 다룬다.
#
# 작성자: 추정된 작성자 또는 블로그명
#
# 내용:
# - Spring Data Redis와 Jackson 간의 직렬화 처리 방식에서 발생하는 문제를 설명.
# - record 데이터 클래스를 사용하여 @Cacheable을 적용할 때 `InvalidTypeIdException` 오류 발생.
# - Jackson이 final 클래스인 record에 대한 타입 정보를 포함하지 않아 역직렬화 실패.
# - 해결책으로는 다른 직렬화기를 사용하거나 Wrapper 클래스를 통해 타입 정보를 포함시키는 방법 제안.
# - DefaultTyping.EVERYTHING 사용 시 성능 저하 우려.
# - record 대신 일반 클래스를 사용하면 Jackson이 자동으로 타입 정보를 붙여 문제 해결 가능.
# - GenericJackson2JsonRedisSerializer의 ObjectMapper 설정은 개발자 책임.
# - 커스텀 TypeResolver를 통해 record 객체에 타입 정보를 추가하는 방법 구현.
# - 테스트 결과, 직렬화 및 역직렬화가 정상적으로 작동함을 확인.
# - 라이브러리의 내부 동작 이해의 중요성을 강조.
# ================================================================================
#
# 🎯 전체 요약 완료: 13개 사이트

# %%
# 최종 결과 요약
print("\n🎯 테스트 완료 - 최종 결과")
print("=" * 60)
print(f"📋 총 테스트 URL: {len(urls)}개")
print(f"✅ 성공한 URL: {len(successful_urls) if 'successful_urls' in locals() else len(site_stats)}개")
print(f"❌ 실패한 URL: {len(failed_urls) if 'failed_urls' in locals() else 0}개")
print(f"📄 총 추출된 청크: {len(final_docs)}개")
print(f"📏 총 콘텐츠 길이: {sum(len(doc.page_content) for doc in final_docs):,}자")

if final_docs:
    avg_chunk_size = sum(len(doc.page_content) for doc in final_docs) // len(final_docs)
    print(f"📊 평균 청크 크기: {avg_chunk_size:,}자")
    
print("\n✨ WebBaseLoader 다중 URL 처리 테스트 완료!")
# Out:
# 🎯 테스트 완료 - 최종 결과
# ============================================================
# 📋 총 테스트 URL: 13개
# ✅ 성공한 URL: 13개
# ❌ 실패한 URL: 0개
# 📄 총 추출된 청크: 28개
# 📏 총 콘텐츠 길이: 80,012자
# 📊 평균 청크 크기: 2,857자
#
# ✨ WebBaseLoader 다중 URL 처리 테스트 완료!
